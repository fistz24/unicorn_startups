# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("final_data.csv")

# %%
df
# Out:
#       Unnamed: 0          Company  Valuation          Date Joined  \
# 0              0        Bytedance        180  2017-04-07 00:00:00
# 1              1           SpaceX        100  2012-12-01 00:00:00
# 2              2            SHEIN        100  2018-07-03 00:00:00
# 3              3           Stripe         95  2014-01-23 00:00:00
# 4              4           Klarna         46  2011-12-12 00:00:00
# ...          ...              ...        ...                  ...
# 1067           7         Assembly          1           2021-09-21
# 1068           8     Carson Group          1           2021-07-14
# 1069           9  Iodine Software          1           2021-12-01
# 1070          10     Kendra Scott          1           2016-12-21
# 1071          11           Poizon          1           2019-04-29
#
#                              Industry           City        Country  \
# 0             Artificial intelligence        Beijing          China
# ...

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#               Company  Valuation          Date Joined  \
# 0           Bytedance        180  2017-04-07 00:00:00
# 1              SpaceX        100  2012-12-01 00:00:00
# 2               SHEIN        100  2018-07-03 00:00:00
# 3              Stripe         95  2014-01-23 00:00:00
# 4              Klarna         46  2011-12-12 00:00:00
# ...               ...        ...                  ...
# 1067         Assembly          1           2021-09-21
# 1068     Carson Group          1           2021-07-14
# 1069  Iodine Software          1           2021-12-01
# 1070     Kendra Scott          1           2016-12-21
# 1071           Poizon          1           2019-04-29
#
#                              Industry           City        Country  \
# 0             Artificial intelligence        Beijing          China
# 1                               Other      Hawthorne  United States
# 2     E-commerce & direct-to-consumer       Shenzhen          China
# ...

# %%
df2 = df.copy()
df2['Select Investors'] = df2['Select Investors'].str.split(', ')

# %%
#In "select investors" column, there're multiple values. This code will split all those values into different rows, which would make analysis easier
df2 = df2.explode('Select Investors')

# %%
# df2[df2['Select Investors'].str.contains('Alibaba')].groupby('Company').value_counts()

# %%
#convert the cleaned data into another csv file
df2.to_csv("cleaned_data.csv")

# %%
# Out:
# Company              object
# Valuation             int64
# Date Joined          object
# Industry             object
# City                 object
# Country              object
# Continent            object
# Year Founded          int64
# Funding             float64
# Select Investors     object
# Year_Joined           int64
# dtype: object
