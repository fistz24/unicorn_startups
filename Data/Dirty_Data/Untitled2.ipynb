# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    Company  Valuation          Date Joined  \
# 0           0  Bytedance        180  2017-04-07 00:00:00
# 1           0  Bytedance        180  2017-04-07 00:00:00
# 2           0  Bytedance        180  2017-04-07 00:00:00
# 3           0  Bytedance        180  2017-04-07 00:00:00
# 4           1     SpaceX        100  2012-12-01 00:00:00
#
#                   Industry       City        Country      Continent  \
# 0  Artificial intelligence    Beijing          China           Asia
# 1  Artificial intelligence    Beijing          China           Asia
# 2  Artificial intelligence    Beijing          China           Asia
# 3  Artificial intelligence    Beijing          China           Asia
# 4                    Other  Hawthorne  United States  North America
#
#    Year Founded  Funding       Select Investors  Year_Joined
# 0          2012      8.0  Sequoia Capital China         2017
# 1          2012      8.0   SIG Asia Investments         2017
# ...

# %%
del df['Unnamed: 0']

# %%
# re-check if all the missing values have been addressed
df.isnull().sum()
# Out:
# Company             0
# Valuation           0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Funding             0
# Select Investors    0
# Year_Joined         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors',
#        'Year_Joined'],
#       dtype='object')

# %%
df['Industry'].nunique()
# Out:
# 16

# %%
df['Industry'].unique()
# Out:
# array(['Artificial intelligence', 'Other',
#        'E-commerce & direct-to-consumer', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery', 'Consumer & retail',
#        'Data management & analytics', 'Edtech', 'Health', 'Hardware',
#        'Auto & transportation', 'Travel', 'Cybersecurity',
#        'Mobile & telecommunications', 'Artificial Intelligence'],
#       dtype=object)

# %%
df.loc[df['Country']=='Indonesia']
# Out:
#       Unnamed: 0        Company  Valuation          Date Joined  \
# 47            16    J&T Express         20  2021-04-07 00:00:00
# 48            16    J&T Express         20  2021-04-07 00:00:00
# 49            16    J&T Express         20  2021-04-07 00:00:00
# 1002         350      Traveloka          3  2017-01-01 00:00:00
# 1003         350      Traveloka          3  2017-01-01 00:00:00
# 1004         350      Traveloka          3  2017-01-01 00:00:00
# 1537         540        Akulaku          2  2022-02-15 00:00:00
# 1538         540        Akulaku          2  2022-02-15 00:00:00
# 1539         540        Akulaku          2  2022-02-15 00:00:00
# 2415         849          Ajaib          1  2021-10-04 00:00:00
# 2416         849          Ajaib          1  2021-10-04 00:00:00
# 2417         849          Ajaib          1  2021-10-04 00:00:00
# 2666         937  Kopi Kenangan          1  2021-12-27 00:00:00
# 2667         937  Kopi Kenangan          1  2021-12-27 00:00:00
# ...
